# %% [markdown]
# # Object-Oriented Programming (OOP) Practice Questions

# %% [markdown]
# 1) Create a class named Rectangle with attributes width and height. Implement methods to calculate
# the area and perimeter of the rectangle.

# %%
#creation of class named Rectangle
class Rectangle:
    def __init__(self, width, height):
        self.width = width
        self.height = height

    #implementation of calculate method
    def calculate(self):
        res = (self.width + self.height) * 2
        return (res)

#example
w = int(input("Give a width of your rectangle: "))
h=int(input("Now, give an heigth: "))
rect = Rectangle(w, h)
print(f"Perimeter of your retangle is: {rect.calculate()}")
# Out:
# Give a width of your rectangle: 5
# Now, give an heigth: 5
# Perimeter of your retangle is: 20

# %% [markdown]
# 2) Write a class named BankAccount that represents a bank account with attributes account_number,
# account_holder_name, and balance. Implement methods to deposit and withdraw money from the
# account while considering balance constraints.

# %%
#class bank account creation
class BankAccount:
    def __init__(self, account_number, account_holder_name, balance):
        self.account_number = account_number
        self.account_holder_name = account_holder_name
        self.balance = balance

    #deposit method
    def deposit(self, amount):
        if amount>0:
            self.balance+=amount
            print(f"Deposit successful. New balance: {self.balance}")
        else:
            print("Invalid deposit amount!")

    #withdraw method
    def withdraw(self, amount):
        if amount<=0:
            print("Invalid withdraw amount")
        elif amount>self.balance:
            print("Insuffisant funds")
        else:
            self.balance-=amount
            print(f"Withdraw succesful. New balance: {self.balance}")

#Evaluation of class Bankaccount
account = BankAccount(123445, "Marie Paul", 100)
print(account.account_holder_name)
account.deposit(int(input("Deposit value: ")))
account.withdraw(int(input("Withdraw value: ")))
# Out:
# Marie Paul
# Deposit value: 90
# Deposit successful. New balance: 190
# Withdraw value: 80
# Withdraw succesful. New balance: 110

# %% [markdown]
# 3) Create a class hierarchy for a game, with a base class Game and derived classes such as Chess,
# Monopoly, and Scrabble. Implement different methods and attributes specific to each game.

# %%
#parent class Game
class Game:
    def __init__(self, name, players):
        self.name = name
        self.players = players
    def start(self):
        print(f"{self.name} is starting with {self.players} players")
    def end(self):
        print(f"{self.name} has ended")

#children class which inherite of game class
class Chess(Game):
    def __init__(self, players):
        super().__init__("Chess", players)
    def start(self):
        super().start()
        print("Let's play Chess")
    def end(self):
        super().end()

class Monopoly(Game):
    def __init__(self, players):
        super().__init__("Monopoly", players)
    def start(self):
        super().start()
        print("Let's play Monopoly")
    def end(self):
        super().end()

class Scrabble(Game):
    def __init__(self, players):
        super().__init__("Scrabble", players)
    def start(self):
        super().start()
        print("Let's play Scrabble")
    def end(self):
        super().end()

#test example
game_players = int(input("Enter the number of players: "))
game1 = Monopoly(game_players)
game1.start()
game1.end()
# Out:
# Enter the number of players: 5
# Monopoly is starting with 5 players
# Let's play Monopoly
# Monopoly has ended

# %% [markdown]
# 4) Implement a class called Car with attributes make, model, and year. Add a class method that
# returns the total count of cars created.

# %%
class Car:
    total_cars = 0 #variable which store total cars created

    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        Car.total_cars+=1 #increment the total count of cars after initialization

    #method which return total count of car created
    @classmethod
    def countCar(cls):
        return cls.total_cars

#creation of some cars
car1 = Car("Honda", "Civic", 2017)
car2 = Car("Toyota", "Corolla", 1994)
car3 = Car("Mercedes", "Benz", 2003)

#called countCar method
print(Car.countCar())
# Out:
# 3

# %% [markdown]
# 5) Design a class called Employee with attributes name, salary, and designation. Implement a
# method that calculates the annual bonus based on the employee's salary and designation.

# %%
class Employee:
    def __init__(self, name, salary, designation):
        self.name = name
        self.salary = salary
        self.designation = designation

    def AnnualBonus(self):
        if self.designation == "Manager":
            bonus_percentage = 0.15
        elif self.designation == "Director":
            bonus_percentage = 0.1
        else:
            bonus_percentage = 0.05
        annual_bonus = self.salary*bonus_percentage
        return annual_bonus

#test class
employee = Employee(input("Input name of employee: "), int(input("Input salary of employee: ")), input("Input designation of employee: "))
bonus = employee.AnnualBonus()
print(f"{employee.name} has {bonus} annual bonus")
# Out:
# Input name of employee: Laure oby
# Input salary of employee: 50000
# Input designation of employee: officer
# Laure oby has 2500.0 annual bonus

# %% [markdown]
# # File Handling Practice Questions

# %% [markdown]
# 1) Write a Python program that reads a text file and counts the occurrences of each word in the file.
# Display the word frequency as a dictionary.

# %%
file = open("data.txt", "w")
file.write("Hello This is the write command. Hello World! ")
file.close()
#function takes file path as parameter
def count_word_frequency(file_path):
    #initialization of empty dictionnary to store the word frequency count
    word_frequency = {}

    #open file and read the file line by line and splits each line into indivuduals words. The split method is used to remove any
    with open(file_path, 'r') as file:
        for line in file:
            words = line.strip().split()
        for word in words:
            #for each word we increment the value of word freqency and get method help to count each word
            word_frequency[word] = word_frequency.get(word, 0) + 1
    return word_frequency

#test exemple
file_path = ("data.txt")
frequency_dict = count_word_frequency(file_path)

#display word frequency
for word, count in frequency_dict.items():
    print(f"{word}: {count}")
# Out:
# Hello: 2
# This: 1
# is: 1
# the: 1
# write: 1
# command.: 1
# World!: 1

# %% [markdown]
# 2) Write a Python function that accepts a directory path as input and recursively lists all file names
# in that directory and its subdirectories.

# %%
import os
from google.colab import drive
drive.mount("/content/drive")

def list_files(dir):
    file_list = []
    #os.walk function generate file names in a directory tree by walking tree by walking the tree either
    #top-down or bottom-up. For each directory visited, os.walk return a tuple containing the root directory, a list
    #of subdirectories and a list of files. Then iterate over the files and append the file paths to the file_list
    for root, dirs, files in os.walk(dir):
        for file in files:
            file_path = os.path.join(root, file)
            file_list.append(file_path)
    return file_list

#test example /home/laureoby/Bureau/DI_article
dir_path = input("Input a directory path: ")
files = list_files(dir_path)
for file in files:
    print(file)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Input a directory path: /content/drive
# /content/drive/MyDrive/MobileOptions.rar
# /content/drive/MyDrive/rapport_soutenance_oby.pdf
# /content/drive/MyDrive/rapport licence oby.pdf
# /content/drive/MyDrive/code m.fendji.rar
# /content/drive/MyDrive/EPREUVE DE TRAITEMENT IMAGE  M2IEAI.doc
# /content/drive/MyDrive/equipe_guide_video.pdf
# /content/drive/MyDrive/equipe_description_creathon.doc
# /content/drive/MyDrive/equipe_depot.pdf
# /content/drive/MyDrive/VobTechGirls_video_creathon.mp4
# /content/drive/MyDrive/teamndéré_description_creathon.doc
# /content/drive/MyDrive/RAPPORT SANTE NUTRITION.docx
# /content/drive/MyDrive/Nutrition_SANTE.docx
# /content/drive/MyDrive/article_CRI (3).pdf
# /content/drive/MyDrive/article_CRI (2).pdf
# /content/drive/MyDrive/article_CRI (1).pdf
# /content/drive/MyDrive/article_CRI.pdf
# /content/drive/MyDrive/demande_recteur.docx
# /content/drive/MyDrive/article oby (1).rar
# /content/drive/MyDrive/article oby.rar
# /content/drive/MyDrive/BGF_Call_2020.pdf
# /content/drive/MyDrive/critère_selection_Carto.docx
# /content/drive/MyDrive/Bourse-Espagne-Filles-Scientif-Delai-14juillet20.jpeg
# /content/drive/MyDrive/call_JFMS_nov_version.pdf
# /content/drive/MyDrive/fetal_health.csv
# /content/drive/MyDrive/AIMS Biodiversity informatics -short (2).pdf
# /content/drive/MyDrive/AIMS Biodiversity informatics -short (1).pdf
# /content/drive/MyDrive/AIMS Biodiversity informatics flyer-long.pdf
# /content/drive/MyDrive/AIMS Biodiversity informatics -short.pdf
# /content/drive/MyDrive/Séminaires bibliographiques Stéphane (1).pdf
# /content/drive/MyDrive/Séminaires bibliographiques Stéphane.pdf
# /content/drive/MyDrive/Obaya_resume (2).pdf
# /content/drive/MyDrive/Obaya_resume (1).pdf
# /content/drive/MyDrive/SUIVI APPRENANTS - FORMATION - ATUT_DOUALA 2021.xlsx
# /content/drive/MyDrive/netflix_titles.csv
# /content/drive/MyDrive/20211106_141509.jpg
# /content/drive/MyDrive/Feuille de calcul sans titre.gsheet
# /content/drive/MyDrive/Obaya_resume.pdf
# /content/drive/MyDrive/Liste des Etudiants.pdf
# /content/drive/MyDrive/20211106_140347.jpg
# /content/drive/MyDrive/IMG_20211201_181040_943.jpg
# /content/drive/MyDrive/20211127_192849.jpg
# /content/drive/MyDrive/RAPPORT SANTE NUTRITION.gdoc
# /content/drive/MyDrive/Untitled0.ipynb
# /content/drive/MyDrive/Untitled1.ipynb
# /content/drive/MyDrive/Untitled (4)
# /content/drive/MyDrive/Untitled (3)
# /content/drive/MyDrive/Untitled (2)
# /content/drive/MyDrive/Untitled (1)
# /content/drive/MyDrive/Untitled2.ipynb
# /content/drive/MyDrive/Telecom_cyberattaque.ipynb
# /content/drive/MyDrive/IMG_20210913_093309_438.jpg
# /content/drive/MyDrive/Demande_Proviseur.docx
# /content/drive/MyDrive/Copie de Demande_Gouverneur.gdoc
# /content/drive/MyDrive/Notes de bienvenue.gdoc
# /content/drive/MyDrive/Questionnaire.gform
# /content/drive/MyDrive/Investment Readiness Program 2023 - Application Questions.pdf.gdrive
# /content/drive/MyDrive/Participation au Adamawa Young Girls ICT Competition.gform
# /content/drive/MyDrive/Invoice WTM Ngaoundere.docx
# /content/drive/MyDrive/CV (1).gdoc
# /content/drive/MyDrive/CV.gdoc
# /content/drive/MyDrive/IMG_5530.JPG
# /content/drive/MyDrive/IMG_5535.JPG
# /content/drive/MyDrive/IMG_5536.JPG
# /content/drive/MyDrive/IMG_5538.JPG
# /content/drive/MyDrive/IMG_5540.JPG
# /content/drive/MyDrive/IMG_5542.JPG
# /content/drive/MyDrive/IMG_5941.jpg
# /content/drive/MyDrive/IMG_5949.jpg
# /content/drive/MyDrive/IMG_5950.jpg
# /content/drive/MyDrive/IMG_6002.jpg
# /content/drive/MyDrive/IMG_6004.jpg
# /content/drive/MyDrive/IMG_6022.jpg
# /content/drive/MyDrive/IMG_6025.jpg
# /content/drive/MyDrive/IMG_6027.jpg
# /content/drive/MyDrive/IMG_6028.jpg
# /content/drive/MyDrive/IMG_6029.jpg
# /content/drive/MyDrive/IMG_6030.jpg
# /content/drive/MyDrive/IMG_6043.jpg
# /content/drive/MyDrive/IMG_6044.jpg
# /content/drive/MyDrive/IMG_6047.jpg
# /content/drive/MyDrive/IMG_6046.jpg
# /content/drive/MyDrive/IMG_6048.jpg
# /content/drive/MyDrive/IMG_6051.jpg
# /content/drive/MyDrive/IMG_6052.jpg
# /content/drive/MyDrive/IMG_6053.jpg
# /content/drive/MyDrive/IMG_6054.jpg
# /content/drive/MyDrive/IMG_6055.jpg
# /content/drive/MyDrive/IMG_6058.jpg
# /content/drive/MyDrive/Appel de speakers pour la IWD23 Ndéré.gform
# /content/drive/MyDrive/CV_Portefolio (3).pdf
# /content/drive/MyDrive/CV_Portefolio (2).pdf
# /content/drive/MyDrive/CV_français (1).pdf
# /content/drive/MyDrive/CV_français.pdf
# /content/drive/MyDrive/PROPOSITION PROGRAMME DE COURS IA.docx
# /content/drive/MyDrive/PROPOSITION DE PROGRAMME DE COURS SUR L’INTELLIGENCE ARTFICIELLE POUR LE VACANCES UTILES DE DE FARA LAB 2023.gdoc
# /content/drive/MyDrive/CV_Portefolio (1).pdf
# /content/drive/MyDrive/CV_Portefolio.pdf
# /content/drive/MyDrive/Proposition menu IO23.xlsx
# /content/drive/MyDrive/Réalisations infographie Obaya.pdf
# /content/drive/MyDrive/tdr.gdoc
# /content/drive/MyDrive/Mureille_Laure Obaya_indaba_certificate (3).pdf
# /content/drive/MyDrive/Mureille_Laure Obaya_indaba_certificate (2).pdf
# /content/drive/MyDrive/Mureille_Laure Obaya_indaba_certificate (1).pdf
# /content/drive/MyDrive/Mureille_Laure Obaya_indaba_certificate.pdf
# /content/drive/MyDrive/GUIDE APPRENANTS  NOUVEAU 21.09.2023.docx
# /content/drive/MyDrive/memoire Master 2.pdf
# /content/drive/MyDrive/CV_Obaya_eng.docx.pdf
# /content/drive/MyDrive/Questions réponses journée 2.gdoc
# /content/drive/MyDrive/Évaluation des sujets à aborder à la WTM Ndere.gform
# /content/drive/MyDrive/apple_quality.csv
# /content/drive/MyDrive/CV_obaya.pdf
# /content/drive/MyDrive/CV_Obaya_eng.pdf
# /content/drive/MyDrive/[WTM International Women's Day] Organizer Guide 2024 "Impact the Future".gslides
# /content/drive/MyDrive/WTM IWD 2024 - Brand guide deck.gslides
# /content/drive/MyDrive/Document sans titre.gdoc
# /content/drive/MyDrive/fruits.zip
# /content/drive/MyDrive/PROPOSITION GROUPE POUR BEL.gdoc
# /content/drive/MyDrive/PROPOSITION GROUPE POUR BEL.pdf
Instagram.gdraw
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Event Custom Social Assets  (To use an asset --> Make a Copy)/Agenda/Option 2/[MAKE A COPY] WTM-IWD23-Agenda-02-LinkedIn.gdraw
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Event Custom Social Assets  (To use an asset --> Make a Copy)/Agenda/Option 1/[MAKE A COPY] WTM-IWD23-Agenda-01-LinkedIn.gdraw
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Event Custom Social Assets  (To use an asset --> Make a Copy)/Agenda/Option 1/[MAKE A COPY] WTM-IWD23-Agenda-01-Twitter.gdraw
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Event Custom Social Assets  (To use an asset --> Make a Copy)/Agenda/Option 1/[MAKE A COPY] WTM-IWD23-Agenda-01-Instagram.gdraw
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Event Custom Social Assets  (To use an asset --> Make a Copy)/Save the Date/[MAKE A COPY] WTM-IWD23-SaveTheDate-Twitter.gdraw
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Event Custom Social Assets  (To use an asset --> Make a Copy)/Save the Date/[MAKE A COPY] WTM-IWD23-SaveTheDate-LinkedIn.gdraw
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Event Custom Social Assets  (To use an asset --> Make a Copy)/Save the Date/[MAKE A COPY] WTM-IWD23-SaveTheDate-Facebook.gdraw
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Event Custom Social Assets  (To use an asset --> Make a Copy)/Speaker Promo/Option 1/[MAKE A COPY] WTM-IWD23-SpeakerPromo-01-Instagram.gdraw
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Event Custom Social Assets  (To use an asset --> Make a Copy)/Speaker Promo/Option 1/[MAKE A COPY] WTM-IWD23-SpeakerPromo-01-Twitter.gdraw
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Event Custom Social Assets  (To use an asset --> Make a Copy)/Speaker Promo/Option 1/[MAKE A COPY] WTM-IWD23-SpeakerPromo-01-LinkedIn.gdraw
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Event Custom Social Assets  (To use an asset --> Make a Copy)/Speaker Promo/Option 2/[MAKE A COPY] WTM-IWD23-SpeakerPromo-02-Twitter.gdraw
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Event Custom Social Assets  (To use an asset --> Make a Copy)/Speaker Promo/Option 2/[MAKE A COPY] WTM-IWD23-SpeakerPromo-02-LinkedIn.gdraw
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Event Custom Social Assets  (To use an asset --> Make a Copy)/Speaker Promo/Option 2/[MAKE A COPY] WTM-IWD23-SpeakerPromo-02-Instagram.gdraw
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Event Custom Social Assets  (To use an asset --> Make a Copy)/Editable Social Asset/Option 4/[MAKE A COPY] WTM-IWD23-EditableSocialAsset_04-Twitter.gdraw
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Event Custom Social Assets  (To use an asset --> Make a Copy)/Editable Social Asset/Option 4/[MAKE A COPY] WTM-IWD23-EditableSocialAsset-04-Instagram.gdraw
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Event Custom Social Assets  (To use an asset --> Make a Copy)/Editable Social Asset/Option 4/[MAKE A COPY] WTM-IWD23-EditableSocialAsset-04-LinkedIn.gdraw
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Event Custom Social Assets  (To use an asset --> Make a Copy)/Editable Social Asset/Option 2/[MAKE A COPY] WTM-IWD23-EditableSocialAsset-02-Instagram.gdraw
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Event Custom Social Assets  (To use an asset --> Make a Copy)/Editable Social Asset/Option 2/[MAKE A COPY] WTM-IWD23-EditableSocialAsset_02-Twitter.gdraw
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Event Custom Social Assets  (To use an asset --> Make a Copy)/Editable Social Asset/Option 2/[MAKE A COPY] WTM-IWD23-EditableSocialAsset-02-LinkedIn.gdraw
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Event Custom Social Assets  (To use an asset --> Make a Copy)/Editable Social Asset/Option 3/[MAKE A COPY] WTM-IWD23-EditableSocialAsset-03-LinkedIn.gdraw
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Event Custom Social Assets  (To use an asset --> Make a Copy)/Editable Social Asset/Option 3/[MAKE A COPY] WTM-IWD23-EditableSocialAsset-03-Instagram.gdraw
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Event Custom Social Assets  (To use an asset --> Make a Copy)/Editable Social Asset/Option 3/[MAKE A COPY] WTM-IWD23-EditableSocialAsset_03-Twitter.gdraw
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Event Custom Social Assets  (To use an asset --> Make a Copy)/Editable Social Asset/Option 1/[MAKE A COPY] WTM-IWD23-EditableSocialAsset_01-Twitter.gdraw
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Event Custom Social Assets  (To use an asset --> Make a Copy)/Editable Social Asset/Option 1/[MAKE A COPY] WTM-IWD23-EditableSocialAsset-01-Instagram.gdraw
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Event Custom Social Assets  (To use an asset --> Make a Copy)/Editable Social Asset/Option 1/[MAKE A COPY] WTM-IWD23-EditableSocialAsset-01-LinkedIn.gdraw
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Stickers /WTM_Sticker_1_v01.gif
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Stickers /WTM_Sticker_2_v01.gif
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Vector Files/WTM-IWD-2023-Agenda.ai
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Vector Files/WTM-IWD23-Email-Header.ai
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Vector Files/WTM-IWD23-EventPage-HeroIllustration.ai
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Vector Files/WTM_IWD2023_EventPageHero.ai
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Vector Files/WTM-IWD-2023-SocialTemplate_Option4.ai
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Vector Files/WTM-IWD-2023-SocialTemplate_Option3.ai
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Vector Files/WTM-IWD-2023-SocialTemplate_Option2.ai
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Vector Files/WTM-IWD-2023-SocialTemplate_Option1.ai
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Vector Files/WTM-IWD-2023-Web-Banners.ai
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Vector Files/WTM-IWD23-Profile-Overlay.ai
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Vector Files/wtm-iwd23-bevy-icon.ai
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Video assets/WTM_2023_Transition_01.mov
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Virtual Backgrounds/WTMIWD_2023_VirtualBackground_01.png
# /content/drive/.shortcut-targets-by-id/1TliWniHxu4h_wj_dya-noHx517zTawNd/WTM IWD 2023: Brand Guide "Dare To Be"/Virtual Backgrounds/WTMIWD_2023_VirtualBackground_02.png
# /content/drive/.shortcut-targets-by-id/11A0hRAL2tChemmipSp1UVZt6B3oCp3UJ/TELECOM_CYBERSECURITE/KDDTrain+.txt
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /WTM IWD 2024 - Brand guide deck.gslides
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Members  WTM IWD 2024 - Brand guide deck.gslides
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Bevy Icon/WTM-IWD-2024-bevy-icon.png
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Bevy Icon/WTM-IWD-2024-bevy-icon.svg
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Email Header/WTM-IWD-2024-email-header.png
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Event Hero/WTM-IWD-2024-hero-2.png
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Event Hero/WTM-IWD-2024-hero-3.png
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Event Hero/WTM-IWD-2024-hero-1.png
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Photography/WTM-IWD-2024-social-photography-option-1.png
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Photography/WTM-IWD-2024-social-photography-option-2.png
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Slide template/Slide Template WTM IWD 2024  .gslides
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Slide template/Copy of Slide Template WTM IWD 2024  .gslides
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Channel banners/Facebook/WTM-IWD-2024-channel-banner-06.png
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Channel banners/LinkedIn/WTM-IWD-2024-channel-banner-05.png
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Channel banners/Twitter/WTM-IWD-2024-channel-banner-07.png
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Lockup/Black/SVG/WTM-IWD-2024-lockup_horiz-logo.svg
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Lockup/Black/SVG/WTM-IWD-2024-lockup_horiz.svg
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Lockup/Black/SVG/WTM-IWD-2024-lockup_vert.svg
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Lockup/Black/SVG/WTM-IWD-2024-lockup_vert-logo.svg
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Lockup/Black/PNG/WTM-IWD-2024-lockup_horiz-logo.png
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Lockup/Black/PNG/WTM-IWD-2024-lockup_vert-logo.png
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Lockup/Black/PNG/WTM-IWD-2024-lockup_vert.png
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Lockup/Black/PNG/WTM-IWD-2024-lockup_horiz.png
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Lockup/Black/PNG/Copy of WTM-IWD-2024-lockup_horiz-logo.png
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Lockup/White/PNG/WTM-IWD-2024-lockup_vert-reverse.png
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Lockup/White/PNG/WTM-IWD-2024-lockup_vert-logo-reverse.png
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Lockup/White/PNG/WTM-IWD-2024-lockup_horiz-reverse.png
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Lockup/White/PNG/WTM-IWD-2024-lockup_horiz-logo-reverse.png
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Lockup/White/SVG/WTM-IWD-2024-lockup_vert-logo-reverse.svg
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Lockup/White/SVG/WTM-IWD-2024-lockup_vert-reverse.svg
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Lockup/White/SVG/WTM-IWD-2024-lockup_horiz-logo-reverse.svg
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Lockup/White/SVG/WTM-IWD-2024-lockup_horiz-reverse.svg
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Illustration Carousel/Carousel-2-social-illustration.gdraw
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Illustration Carousel/Carousel-1-social-illustration.png
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Save the Date Promo/Save the Date Promo - Twitter LinkedIn.gdraw
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Save the Date Promo/Save the Date Promo - Insta.gdraw
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Profile Avatar/WTM IWD 2024 - Profile Avatar.gdraw
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Agenda Template/Agenda Template - Twitter LinkedIn.gdraw
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Agenda Template/Agenda Template - Insta.gdraw
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Promotional templates/Option 1/Editable Template - Option 1 - Twitter LinkedIn.gdraw
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Promotional templates/Option 1/Editable Template - Option 1 - Insta [make a copy].gdraw
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Promotional templates/Option 2/Editable Template - Option 2 - Twitter LinkedIn.gdraw
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Promotional templates/Option 2/Editable Template - Option 2 - Insta.gdraw
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Promotional templates/Option 3/Editable Template - Option 3 - Insta.gdraw
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Promotional templates/Option 3/Editable Template - Option 3 - Twitter LinkedIn.gdraw
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Promotional templates/Option 4/Editable Template - Option 4 - Insta.gdraw
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Promotional templates/Option 4/Editable Template - Option 4 - Twitter LinkedIn [make a copy].gdraw
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Speaker Promo Template/Speaker Promo - Twitter LinkedIn.gdraw
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Speaker Promo Template/Speaker Promo - Insta.gdraw
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Promotional gif/WTM_IWD_2024_PromotionalGif_v01.gif
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Stickers /WTM_IWD_2024_Sticker_01_v01.gif
# /content/drive/.shortcut-targets-by-id/1QMx24TRJBY9IfN7JSwvmgTGMFA9IKJ3L/WTM IWD 2024 Assets /Stickers /WTM_IWD_2024_Sticker_02_v01.gif

# %% [markdown]
# 3) Create a program that reads an image file, applies a grayscale filter to it, and saves the modified
# image as a new file.

# %%
#The library called Pillow (PIL) is used to read, modify and save images files
from PIL import Image
from google.colab import drive
drive.mount("/content/drive")

def grayscaleFilter(img_path, output_path):
    #open the image file
    img = Image.open(img_path)

    #convert image to grayscale
    grayscale_img = img.convert("L")

    #save the modified image
    grayscale_img.save(output_path)
    print(f"Image convert to grayscale save in: {output_path}")

#test example /content/drive/MyDrive/IMG_5540.JPG and for grayscale image /content/drive/MyDrive/grayscale.jpg
img_path = input("Input path of original image: ")
output_path = input("Input path of grayscale image as path/name_of_future_grayscale_picture.extension: ")

#called function
grayscaleFilter(img_path, output_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Input path of original image: /content/drive/MyDrive/IMG_5540.JPG
# Input path of grayscale image as path/name_of_future_grayscale_picture.extension: /content/drive/MyDrive/grayscale.jpg
# Image convert to grayscale save in: /content/drive/MyDrive/grayscale.jpg
